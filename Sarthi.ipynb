# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Sarthimarks.csv')

# %%
df.head()
# Out:
#    GUJCET Percentile  Board Percentile  Predicted Rank
# 0          72.928810         82.911362            8824
# 1          91.476737         90.835104            3412
# 2          78.753647         66.255233           12071
# 3          43.402779         56.359378           26106
# 4          87.503502         71.733695            8589

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df.corr()
# Out:
#                    GUJCET Percentile  Board Percentile  Predicted Rank
# GUJCET Percentile            1.00000           0.16575        -0.65262
# Board Percentile             0.16575           1.00000        -0.84404
# Predicted Rank              -0.65262          -0.84404         1.00000

# %%
df.isna().sum()
# Out:
# GUJCET Percentile    0
# Board Percentile     0
# Predicted Rank       0
# dtype: int64

# %%
X=df.drop(columns=['Predicted Rank'])
Y=df['Predicted Rank']

# %%
X
# Out:
#     GUJCET Percentile  Board Percentile
# 0           72.928810         82.911362
# 1           91.476737         90.835104
# 2           78.753647         66.255233
# 3           43.402779         56.359378
# 4           87.503502         71.733695
# ..                ...               ...
# 95          41.827178         84.819654
# 96          94.223184         45.005346
# 97          83.901625         42.736878
# 98          57.528852         54.449727
# 99          43.782297         73.338955
#
# [100 rows x 2 columns]

# %%
Y
# Out:
# 0      8824
# 1      3412
# 2     12071
# 3     26106
# 4      8589
#       ...
# 95    14650
# 96    16095
# 97    19164
# 98    22501
# 99    17814
# Name: Predicted Rank, Length: 100, dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.3,random_state=42)

# %%
from sklearn.metrics import r2_score

# %%
reg=LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=reg.predict(X_test)

# %%
reg.intercept_
# Out:
# 54322.61991515967

# %%
reg.coef_
# Out:
# array([-227.28257091, -347.59251678])

# %%
reg.score(X_train,y_train)
# Out:
# 0.9842952366458619

# %%
reg.score(X_test,y_test)
# Out:
# 0.9739926699482645

# %%
r2 = r2_score(y_test, y_pred)

# %%
print("R2 score is: ",r2)
# Out:
# R2 score is:  0.9739926699482645

# %%
reg.predict([[90,90]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 reg.predict([[90,90]])
#
# NameError: name 'reg' is not defined
